# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd

points = pd.read_csv('BA_Exp2_Trajectory.csv',sep=';')

fig = plt.figure()
ax = fig.add_subplot(111)

x = points['xPos'].values
y = points['yPos'].values
actions = points['input'].values

x_transformed = (x - 50) / 10
y_transformed = (y - 50) / 10

ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

ax.plot(x_transformed, y_transformed, c='#0077B6')

action_label_set = False;

for i, action in enumerate(actions):
    if i == 0:
        continue
        
    if(action != 'Unknown'):
        if not action_label_set:
            plt.plot( x_transformed[i], y_transformed[i], c="#0077B6", marker="x", mec="red", label="Befehl")
        elif action_label_set == True:
            plt.plot( x_transformed[i], y_transformed[i], c="#0077B6", marker="x", mec="red")
        plt.text( x_transformed[i] + 0.02, y_transformed[i] + 0.02, action, fontsize=9)
        action_label_set = True
 
ax.set_xlim(-0.1, 1.5)
ax.set_ylim(-0.2, 2)

ax.grid(True)

plt.legend()

plt.savefig('Exp2_DemoTraj.pdf', format='pdf')

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd
import os

csv_files = ['Wiederholungen/Exe1.csv', 'Wiederholungen/Exe2.csv', 'Wiederholungen/Exe3.csv', 
             'Wiederholungen/Exe4.csv', 'Wiederholungen/Exe5.csv', 'Wiederholungen/Exe6.csv', 
             'Wiederholungen/Exe7.csv', 'Wiederholungen/Exe8.csv', 'Wiederholungen/Exe9.csv', 
             'Wiederholungen/Exe10.csv', 'BA_Exp2_Trajectory.csv' ]

fig, ax = plt.subplots()
set_retry_label = False;

for csv_file in csv_files:
    # Lade die Daten aus der CSV-Datei
    df = pd.read_csv(csv_file, sep=';')
    
    x = df['xPos'].values
    y = df['yPos'].values

    x_transformed = (x - 50) / 10
    y_transformed = (y - 50) / 10

    if os.path.basename(csv_file) == 'BA_Exp2_Trajectory.csv':
        ax.plot(x_transformed, y_transformed, c="#0077B6", label="Soll-Trajektion")
    else:
        if not set_retry_label:
            ax.plot(x_transformed, y_transformed, c="orange", label="Ist-Trajektion")
            set_retry_label = True;
        else:
            ax.plot(x_transformed, y_transformed, c="orange")
        

ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')
ax.legend();
ax.grid(True)

plt.savefig('Exp2_ÜberlapptTraj.pdf', format='pdf')

plt.show()

# %%
import pandas as pd

#csv_files = ['Wiederholungen/Exe3.csv', 'Wiederholungen/Exe1.csv', 'Wiederholungen/Exe6.csv', 
#             'Wiederholungen/Exe8.csv', 'Wiederholungen/Exe9.csv', 'Wiederholungen/Exe11.csv', 
#             'Wiederholungen/Exe7.csv', 'Wiederholungen/Exe12.csv', 'Wiederholungen/Exe18.csv', 
#             'Wiederholungen/Exe19.csv', 'BA_Exp2_Trajectory.csv' ]

all_row_by_files = []  # 2D array, in der alle zeilen jeder Datei eingefügt ist

first_action = []
second_action = []
third_action = []
fourth_action = []
fifth_action = []
sixth_action = []
seventh_action = []
eigth_action = []
ninth_action = []
tenth_action = []
eleventh_action = []
twelfth_action = []
thirdteenth_action = []
fourteenth_action = []

# Filtere aus allen Dtein die unerwünschten Attribute heraus.
for csv_file in csv_files:
    df = pd.read_csv(csv_file, sep=";")
    filtered_df = df[df['input'] != 'Unknown']
    filtered_df = filtered_df[filtered_df['input'] != 'Connect']
    filtered_df = filtered_df[filtered_df['input'] != 'StopRrNavigationRecording']
    filtered_df = filtered_df[filtered_df['input'] != 'StartRrNavigation']
    
    all_row_by_files.append(filtered_df.values)

for row in all_row_by_files:
    first_action.append(row[0])
    second_action.append(row[1])
    third_action.append(row[2])
    fourth_action.append(row[3])
    fifth_action.append(row[4])
    sixth_action.append(row[5])
    seventh_action.append(row[6])
    eigth_action.append(row[7])
    ninth_action.append(row[8])
    tenth_action.append(row[9])
    eleventh_action.append(row[10])
    twelfth_action.append(row[11])
    thirdteenth_action.append(row[12])
    fourteenth_action.append(row[12])

abweichungs_koordinaten = []
#print(first_action)
#print(second_action)
#print(third_action)
#print(fourth_action)
#print(fifth_action)
#print(sixth_action)
#print(seventh_action)
#print(eigth_action)
#print(ninth_action)
#print(tenth_action)
#print(eleventh_action)
#print(twelfth_action)
#print(thirdteenth_action)
#print(fourtenth_action)

# %%
# Aktion 1 - TakeOff
curr_action = first_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10
shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
#ax.set_xlim(-0.2, 0.2)
#ax.set_ylim(-0.2, 0.2)

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
# Zeichne das Koordinatensystem

plt.savefig('Exp2_OhneTol_Act1.pdf', format='pdf')
ax.legend()
print(len(first_action))
plt.show()
# Out:
# 11

# %%
# Aktion 2 - MoveForward
curr_action = second_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10
shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.2, 0.2)
ax.set_ylim(-0.2, 0.2)


ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
ax.legend()
plt.savefig('Exp2_OhneTol_Act2.pdf', format='pdf')

plt.show()

# %%
# Aktion 3 - Stop
curr_action = third_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.65, 0.65)
ax.set_ylim(-0.65, 0.65)

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koodinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act3.pdf', format='pdf')

plt.show()

# %%
# Aktion 4 - MoveRight
curr_action = fourth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.5, 0.5)
ax.set_ylim(-0.5, 0.5)


ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act4.pdf', format='pdf')

plt.show()

# %%
# Aktion 5 - Stop
curr_action = fifth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen

ax.set_xlim(-0.6, 0.6)
ax.set_ylim(-0.6, 0.6)


ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act5.pdf', format='pdf')

plt.show()

# %%
# Aktion 6 - MoveBackwards
curr_action = sixth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.45, 0.45)
ax.set_ylim(-0.45, 0.45)


ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act6.pdf', format='pdf')

plt.show()

# %%
# Aktion 7 - Stop
curr_action = seventh_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.65, 0.65)
ax.set_ylim(-0.65, 0.65)


ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act7.pdf', format='pdf')

plt.show()

# %%
# Aktion 8 - MoveRight
curr_action = eigth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.8, 0.8)
ax.set_ylim(-0.8, 0.8)


ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act8.pdf', format='pdf')

plt.show()

# %%
# Aktion 9 - Stop
curr_action = ninth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.8, 0.8)
ax.set_ylim(-0.8, 0.8)

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act9.pdf', format='pdf')

plt.show()

# %%
# Aktion 10 - MoveBackwards
curr_action = tenth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.8, 0.8)
ax.set_ylim(-0.8, 0.8)

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act10.pdf', format='pdf')

plt.show()

# %%
# Aktion 11 - Stop
curr_action = eleventh_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3] - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.8, 0.8)
ax.set_ylim(-0.8, 0.8)

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act11.pdf', format='pdf')

plt.show()

# %%
# Aktion 12 - StoMoveLeftp
curr_action = twelfth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3]  - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

ax.set_xlim(-0.8, 0.8)
ax.set_ylim(-0.8, 0.8)

# Füge Achsentitel hinzu
ax.set_xlabel('x_b in m')
ax.set_ylabel('y_b in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
   
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act12.pdf', format='pdf')

plt.show()

# %%
# Aktion 13 - Stop
curr_action = thirdteenth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3] - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel('x_b in m')
ax.set_ylabel('y_b in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act13.pdf', format='pdf')

plt.show()

# %%
# Aktion 14 - Land
curr_action = fourteenth_action
origin = curr_action[-1]
origin_x = (origin[2] - 50) / 10 # skaliere von cm in m und versetze die pos auf (0,0)
origin_y = (origin[3] - 50) / 10

shift_x = origin_x
shift_y = origin_y

shifted_origin_x = origin_x - shift_x
shifted_origin_y = origin_y - shift_y

fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.8, 0.8)
ax.set_ylim(-0.8, 0.8)

ax.plot(shifted_origin_x, shifted_origin_y, marker='o', color='#0077B6', label='Soll-Koordinate')

label_set = False;

for i in range(len(curr_action) - 1):
    pointX = ((curr_action[i][2]  - 50) / 10) - shift_x
    pointY = ((curr_action[i][3]  - 50) / 10) - shift_y
    abweichungs_koordinaten.append((pointX, pointY))

    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()

plt.savefig('Exp2_OhneTol_Act14.pdf', format='pdf')

plt.show()

# %%
# Aktion 13 - Land
fig, ax = plt.subplots()

ax.axhline(y=shifted_origin_y, color='gray')  # Horizontale Linie durch den Ursprung
ax.axvline(x=shifted_origin_x, color='gray')  # Vertikale Linie durch den Ursprung

# Füge Achsentitel hinzu
ax.set_xlabel(r'$x_b$ in m')
ax.set_ylabel(r'$y_b$ in m')

# Setze das Koordinatensystem mit angepassten Achsenbegrenzungen
ax.set_xlim(-0.8, 0.8)
ax.set_ylim(-0.8, 0.8)



label_set = False;

for i in range(len(abweichungs_koordinaten) - 1):
   
    pointX = abweichungs_koordinaten[i][0]
    pointY = abweichungs_koordinaten[i][1]
    
    if not label_set:
        ax.plot(pointX, pointY, marker='o', color='orange', label='Ist-Koordinate')
        label_set = True
    else:
        ax.plot(pointX, pointY, marker='o', color='orange')
        
ax.plot(0, 0, marker='o', color='#0077B6', label='Soll-Koordinate')
ax.grid(True)
# Zeichne das Koordinatensystem
ax.legend()
plt.savefig('Exp2_OhneTol_Heatmap.pdf', format='pdf')

plt.show()
